# %% [markdown]
# # Classify and Reasoning Colab workplace
#
# Use this notebook as the A100 workplace, or open `workplace/colab_worker.ipynb`.
#
# Local Cursor runs the gateway. This machine only runs GPU jobs from the Drive queue.

# %%
from google.colab import drive
import torch

assert torch.cuda.is_available(), "Runtime → Change runtime type → GPU → A100"
print("GPU:", torch.cuda.get_device_name(0))

drive.mount("/content/drive")

# %%
# !pip install -q -U transformers accelerate peft bitsandbytes datasets pillow

# %%
# !python /content/drive/MyDrive/classify_and_reasoning_qwen3-vlm8b/workplace/worker.py
